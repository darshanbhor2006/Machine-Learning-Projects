# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Churn_Modelling.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602        NaN          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# #### Problem Statement

# %% [raw]
# The bank aims to minimize customer attrition by identifying customers who are likely to discontinue their relationship with the bank. Using historical customer data, the goal is to develop a predictive analytics model that enables proactive engagement and personalized retention efforts.

# %%
data.head()#first five rows(records)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602       NaN          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data.tail()#last five rows(records)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
data[1001:1100]
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 1001       1002    15592089     Larsen          788    France  Female   43
# 1002       1003    15633897       Owen          725   Germany    Male   39
# 1003       1004    15701301     Murphy          646    France  Female   42
# 1004       1005    15723685  Ekechukwu          601   Germany  Female   26
# 1005       1006    15701602      Ayers          521   Germany    Male   52
# ...         ...         ...        ...          ...       ...     ...  ...
# 1095       1096    15689081         Wu          692    France    Male   29
# 1096       1097    15813168    Maslova          756   Germany  Female   39
# 1097       1098    15604295        Wei          543    France    Male   36
# 1098       1099    15724127     McLean          790    France  Female   26
# 1099       1100    15673055       Sung          494     Spain    Male   38
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 1001      10       0.00              2          1               1
# 1002       1   50880.98              2          1               1
# 1003       3  175159.90              2          0               0
# 1004       7  105514.69              2          1               0
# 1005       5  116497.31              3          0               0
# ...      ...        ...            ...        ...             ...
# 1095       4       0.00              1          1               0
# 1096       3  100717.85              3          1               1
# 1097       6       0.00              2          1               0
# 1098       4  141581.71              2          0               0
# 1099       7       0.00              2          1               1
#
#       EstimatedSalary  Exited
# 1001        116111.51       0
# 1002        184023.54       0
# 1003         67124.48       1
# 1004         50070.59       0
# 1005         53793.10       1
# ...               ...     ...
# 1095         76755.99       1
# 1096         73406.04       1
# 1097        176728.28       0
# 1098         98309.27       0
# 1099          6203.66       0
#
# [99 rows x 14 columns]

# %%
data[1001:1100:2]
# Out:
#       RowNumber  CustomerId       Surname  CreditScore Geography  Gender  Age  \
# 1001       1002    15592089        Larsen          788    France  Female   43
# 1003       1004    15701301        Murphy          646    France  Female   42
# 1005       1006    15701602         Ayers          521   Germany    Male   52
# 1007       1008    15573086        Millar          564    France    Male   42
# 1009       1010    15750765       Sanders          650     Spain    Male   71
# 1011       1012    15698442   Eberechukwu          719     Spain    Male   35
# 1013       1014    15603594       Nwankwo          635     Spain    Male   24
# 1015       1016    15686936      McGregor          676    France  Female   37
# 1017       1018    15587451         Goold          778   Germany    Male   41
# 1019       1020    15600583        Garner          633    France    Male   31
# 1021       1022    15717164      Genovese          485     Spain    Male   32
# 1023       1024    15682639      Marshall          642    France    Male   32
# 1025       1026    15759805         Pinto          582    France  Female   32
# 1027       1028    15769948       Palerma          737   Germany    Male   35
# 1029       1030    15688071       Collins          609     Spain    Male   53
# 1031       1032    15667521      Crawford          631    France  Female   22
# 1033       1034    15695475       Maclean          645    France    Male   29
# 1035       1036    15652955         Price          678     Spain    Male   30
# 1037       1038    15631054       Volkova          625    France  Female   24
# 1039       1040    15577478         Ch'iu          714    France  Female   72
# 1041       1042    15692317         Craig          722    France    Male   30
# 1043       1044    15570417         Chien          579    France    Male   35
# 1045       1046    15785980     Williford          588     Spain    Male   34
# 1047       1048    15793949         Cheng          726    France  Female   48
# 1049       1050    15705860      McKenzie          631   Germany    Male   40
# 1051       1052    15715003            Ko          625     Spain  Female   49
# 1053       1054    15798348   Chukwuebuka          600     Spain  Female   50
# 1055       1056    15769499  Lampungmeiua          545     Spain  Female   74
# 1057       1058    15706534     Enyinnaya          581    France  Female   47
# 1059       1060    15812197         Kline          850    France    Male   38
# 1061       1062    15692991          Wood          710     Spain  Female   38
# 1063       1064    15762198         Capon          812    France    Male   34
# 1065       1066    15692744       Davison          512    France    Male   36
# 1067       1068    15599131         Dilke          650   Germany    Male   26
# 1069       1070    15628674       Iadanza          844    France    Male   40
# 1071       1072    15586970         Pinto          695   Germany    Male   52
# 1073       1074    15790497          Ross          503     Spain    Male   37
# 1075       1076    15762937       Chiganu          743   Germany  Female   32
# 1077       1078    15729832         Cheng          658    France    Male   29
# 1079       1080    15748856         Liang          664    France    Male   32
# 1081       1082    15699911       Chapman          461     Spain  Female   35
# 1083       1084    15692583       Udobata          678    France  Female   32
# 1085       1086    15646513         Spyer          803    France    Male   42
# 1087       1088    15696098       Palermo          498    France  Female   31
# 1089       1090    15649744       Fallaci          628    France  Female   51
# 1091       1092    15784092     Henderson          732    France    Male   36
# 1093       1094    15624347        Fokine          651    France    Male   40
# 1095       1096    15689081            Wu          692    France    Male   29
# 1097       1098    15604295           Wei          543    France    Male   36
# 1099       1100    15673055          Sung          494     Spain    Male   38
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 1001      10       0.00              2          1               1
# 1003       3  175159.90              2          0               0
# 1005       5  116497.31              3          0               0
# 1007       7   99824.45              1          1               1
# 1009       0       0.00              1          1               1
# 1011       3  122964.88              1          1               1
# 1013       4       0.00              2          1               1
# 1015       5   89634.69              1          1               1
# 1017       7  139706.31              1          1               0
# 1019       1       0.00              1          1               0
# 1021       6  102238.01              2          1               1
# 1023       3       0.00              2          1               1
# 1025       4       0.00              2          1               0
# 1027       0  133377.80              1          0               1
# 1029      10       0.00              1          1               1
# 1031       3       0.00              2          0               0
# 1033       1  130131.08              2          0               1
# 1035       0       0.00              1          1               0
# 1037       1       0.00              2          1               1
# 1039       3       0.00              1          1               1
# 1041       5       0.00              2          1               0
# 1043       1       0.00              2          1               0
# 1045       6  121132.26              2          1               0
# 1047       4       0.00              1          1               0
# 1049       3  107949.45              1          1               0
# 1051       2   80816.45              1          1               1
# 1053       6   94684.27              1          1               1
# 1055       3       0.00              2          1               1
# 1057       1  122949.14              1          0               0
# 1059       7   80293.98              1          0               0
# 1061       4       0.00              2          1               1
# 1063       5  103818.43              1          1               1
# 1065       4  152169.12              2          0               0
# 1067       4  214346.96              2          1               0
# 1069       7  113348.14              1          1               0
# 1071       8  103023.26              1          1               1
# 1073       6       0.00              2          0               0
# 1075       6  140348.56              2          1               1
# 1077       3  145512.84              1          1               0
# 1079      10  107209.73              1          1               1
# 1081       8       0.00              1          1               0
# 1083       5       0.00              2          1               0
# 1085       5       0.00              1          1               0
# 1087      10       0.00              2          1               0
# 1089       3  123981.31              2          1               1
# 1091       7  126195.81              1          1               1
# 1093       4       0.00              2          1               1
# 1095       4       0.00              1          1               0
# 1097       6       0.00              2          1               0
# 1099       7       0.00              2          1               1
#
#       EstimatedSalary  Exited
# 1001        116111.51       0
# 1003         67124.48       1
# 1005         53793.10       1
# 1007         36721.40       0
# 1009        175380.77       0
# 1011        138231.70       0
# 1013         70668.77       0
# 1015        169583.18       1
# 1017         63337.19       0
# 1019         48606.71       0
# 1021        194010.12       0
# 1023         88698.83       0
# 1025         59668.81       0
# 1027         64050.19       0
# 1029        154642.91       0
# 1031         30781.77       0
# 1033        196474.35       0
# 1035         35113.08       0
# 1037        180969.55       0
# 1039         86733.61       0
# 1041        166376.54       0
# 1043          4460.20       0
# 1045         86460.28       0
# 1047        114020.06       1
# 1049         52449.62       1
# 1051         20018.79       0
# 1053         50488.91       0
# 1055        161326.73       0
# 1057        180251.68       1
# 1059        126555.74       0
# 1061        136390.88       0
# 1063        166038.27       0
# 1065         38629.30       1
# 1067        128815.33       0
# 1069         31904.31       1
# 1071         22485.64       0
# 1073        136506.86       0
# 1075        163254.39       0
# 1077         20207.02       0
# 1079        112340.20       0
# 1081        132295.95       0
# 1083         90284.47       0
# 1085        196466.83       1
# 1087         13892.57       0
# 1089         40546.15       0
# 1091        133172.48       0
# 1093        147715.83       0
# 1095         76755.99       1
# 1097        176728.28       0
# 1099          6203.66       0

# %%
data.isnull()
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0         False       False     True        False      False   False  False
# 1         False       False    False        False      False   False  False
# 2         False       False    False        False      False   False  False
# 3         False       False    False        False      False   False  False
# 4         False       False    False        False      False   False  False
# ...         ...         ...      ...          ...        ...     ...    ...
# 9995      False       False    False        False      False   False  False
# 9996      False       False    False        False      False   False  False
# 9997      False       False    False        False      False   False  False
# 9998      False       False    False        False      False   False  False
# 9999      False       False    False        False      False   False  False
#
#       Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0      False    False          False      False           False
# 1      False    False          False      False           False
# 2      False    False          False      False           False
# 3      False    False          False      False           False
# 4      False    False          False      False           False
# ...      ...      ...            ...        ...             ...
# 9995   False    False          False      False           False
# 9996   False    False          False      False           False
# 9997   False    False          False      False           False
# 9998   False    False          False      False           False
# 9999   False    False          False      False           False
#
#       EstimatedSalary  Exited
# 0               False   False
# 1               False   False
# 2               False   False
# 3               False   False
# 4               False   False
# ...               ...     ...
# 9995            False   False
# 9996            False   False
# 9997            False   False
# 9998            False   False
# 9999            False   False
#
# [10000 rows x 14 columns]

# %%
## missing values check
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            1
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          9999 non-null   object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# Converison of categorical data
Geography = pd.get_dummies(data.Geography, drop_first = True)

# %%
Geography
# Out:
#       Germany  Spain
# 0       False  False
# 1       False   True
# 2       False  False
# 3       False  False
# 4       False   True
# ...       ...    ...
# 9995    False  False
# 9996    False  False
# 9997    False  False
# 9998     True  False
# 9999    False  False
#
# [10000 rows x 2 columns]

# %%
Gender = pd.get_dummies(data.Gender, drop_first=True)

# %%
Gender
# Out:
#        Male
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 9995   True
# 9996   True
# 9997  False
# 9998   True
# 9999  False
#
# [10000 rows x 1 columns]

# %%
data = pd.concat([data, Geography, Gender], axis=1)

# %%
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602        NaN          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited  Germany  Spain   Male
# 0           101348.88       1    False  False  False
# 1           112542.58       0    False   True  False
# 2           113931.57       1    False  False  False
# 3            93826.63       0    False  False  False
# 4            79084.10       0    False   True  False
# ...               ...     ...      ...    ...    ...
# 9995         96270.64       0    False  False   True
# 9996        101699.77       0    False  False   True
# 9997         42085.58       1    False  False  False
# 9998         92888.52       1     True  False   True
# 9999         38190.78       0    False  False  False
#
# [10000 rows x 17 columns]

# %%
data.drop(['Geography','Gender'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Age  Tenure    Balance  \
# 0          1    15634602       NaN          619   42       2       0.00
# 1          2    15647311      Hill          608   41       1   83807.86
# 2          3    15619304      Onio          502   42       8  159660.80
# 3          4    15701354      Boni          699   39       1       0.00
# 4          5    15737888  Mitchell          850   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  Germany  \
# 0              1          1               1        101348.88       1    False
# 1              1          0               1        112542.58       0    False
# 2              3          1               0        113931.57       1    False
# 3              2          0               0         93826.63       0    False
# 4              1          1               1         79084.10       0    False
#
#    Spain   Male
# 0  False  False
# 1   True  False
# 2  False  False
# 3  False  False
# 4   True  False

# %%
data.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Age', 'Tenure',
#        'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited', 'Germany', 'Spain', 'Male'],
#       dtype='object')

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Age  Tenure    Balance  \
# 0          1    15634602       NaN          619   42       2       0.00
# 1          2    15647311      Hill          608   41       1   83807.86
# 2          3    15619304      Onio          502   42       8  159660.80
# 3          4    15701354      Boni          699   39       1       0.00
# 4          5    15737888  Mitchell          850   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  Germany  \
# 0              1          1               1        101348.88       1    False
# 1              1          0               1        112542.58       0    False
# 2              3          1               0        113931.57       1    False
# 3              2          0               0         93826.63       0    False
# 4              1          1               1         79084.10       0    False
#
#    Spain   Male
# 0  False  False
# 1   True  False
# 2  False  False
# 3  False  False
# 4   True  False

# %%
## Creating independent and dependent variable.
X = data.loc[: , ['CreditScore', 'Age', 'Tenure','Balance', 'NumOfProducts', 'HasCrCard',
                'IsActiveMember', 'EstimatedSalary','Germany', 'Spain', 'Male']]   #input/featues
y = data.Exited  #data["Exited"]   #output/target

# %%
X
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain   Male
# 0                  1        101348.88    False  False  False
# 1                  1        112542.58    False   True  False
# 2                  0        113931.57    False  False  False
# 3                  0         93826.63    False  False  False
# 4                  1         79084.10    False   True  False
# ...              ...              ...      ...    ...    ...
# 9995               0         96270.64    False  False   True
# 9996               1        101699.77    False  False   True
# 9997               1         42085.58    False  False  False
# 9998               0         92888.52     True  False   True
# 9999               0         38190.78    False  False  False
#
# [10000 rows x 11 columns]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
## Training and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=20, test_size = 0.2)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.shape
# Out:
# (8000, 11)

# %%
X_test.shape
# Out:
# (2000, 11)

# %%
X_train
# Out:
# array([[ 1.34111823,  0.38693948, -1.73661451, ..., -0.57965968,
#         -0.58042949, -1.08948952],
#        [-1.4670728 , -0.57127623,  0.69033796, ..., -0.57965968,
#         -0.58042949,  0.91786105],
#        [-0.19155746, -1.62531351, -0.69649202, ..., -0.57965968,
#         -0.58042949, -1.08948952],
#        ...,
#        [ 0.5079187 ,  1.44097676, -0.69649202, ...,  1.72515018,
#         -0.58042949, -1.08948952],
#        [-2.25912668, -0.76291937, -0.00307703, ..., -0.57965968,
#         -0.58042949,  0.91786105],
#        [-0.78816947,  1.05769048, -1.73661451, ..., -0.57965968,
#          1.72286214,  0.91786105]], shape=(8000, 11))

# %%
X_test
# Out:
# array([[-0.17098463, -1.3378488 , -1.38990701, ..., -0.57965968,
#         -0.58042949,  0.91786105],
#        [ 2.06116722, -0.18798994, -0.34978452, ..., -0.57965968,
#          1.72286214,  0.91786105],
#        [ 0.52849152,  0.48276105,  0.69033796, ..., -0.57965968,
#         -0.58042949,  0.91786105],
#        ...,
#        [-0.91160644, -1.05038408,  0.34363047, ..., -0.57965968,
#          1.72286214,  0.91786105],
#        [-1.29220376, -0.95456251,  1.38375295, ...,  1.72515018,
#         -0.58042949,  0.91786105],
#        [ 1.00166657,  0.19529634, -0.00307703, ..., -0.57965968,
#         -0.58042949,  0.91786105]], shape=(2000, 11))

# %% [markdown]
# ##### Import Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import(accuracy_score, confusion_matrix, classification_report)

# %% [markdown]
# ##### Create the Random Forest model

# %%
rf_model = RandomForestClassifier(n_estimators=100, criterion='gini',random_state=42)

# %% [markdown]
# ##### Train the model

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# ##### Predict on test data

# %%
y_pred = rf_model.predict(X_test)

# %%
y_pred   #predicted
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(2000,))

# %%
y_test    #actual
# Out:
# 9957    0
# 1687    0
# 2116    0
# 231     0
# 2780    0
#        ..
# 7176    0
# 5050    0
# 7910    0
# 7023    0
# 2054    0
# Name: Exited, Length: 2000, dtype: int64

# %% [markdown]
# ##### Accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.874

# %% [markdown]
# ##### Confusion Matrix

# %%
cm = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[1567   56]
#  [ 196  181]]

# %%
(1550+183)/2000
# Out:
# 0.8665

# %% [markdown]
# ##### Classification Report

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93      1623
#            1       0.76      0.48      0.59       377
#
#     accuracy                           0.87      2000
#    macro avg       0.83      0.72      0.76      2000
# weighted avg       0.87      0.87      0.86      2000

# %% [markdown]
# ##### Feature Importance

# %%
import pandas as pd
import matplotlib.pyplot as plt

feature_importance = pd.DataFrame({'Feature': X.columns,
                                   'Importance': rf_model.feature_importances_})

feature_importance = feature_importance.sort_values(by='Importance',ascending=False)

print(feature_importance)
# Out:
#             Feature  Importance
# 1               Age    0.243617
# 7   EstimatedSalary    0.144415
# 3           Balance    0.142782
# 0       CreditScore    0.141423
# 4     NumOfProducts    0.127223
# 2            Tenure    0.080696
# 6    IsActiveMember    0.042161
# 8           Germany    0.027391
# 10             Male    0.018164
# 5         HasCrCard    0.017627
# 9             Spain    0.014500

# %% [markdown]
# ##### Visualize a feature importance

# %%
plt.figure(figsize=(8,5))
plt.barh(feature_importance['Feature'], feature_importance['Importance'])
plt.xlabel("Importance")
plt.ylabel("Features")
plt.title("Random Forest Feature Importance")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ##### Save the Churn Model

# %%
import pickle
# Save Random Forest model
pickle.dump(rf_model, open("random_forest_churn_model.pkl", "wb"))

# Save Scaler
pickle.dump(sc, open("scaler.pkl", "wb"))

print("random_forest_churn_model.pkl and scaler.pkl saved successfully.")
# Out:
# random_forest_churn_model.pkl and scaler.pkl saved successfully.

# %% [markdown]
# ##### Load the Model for Later Use

# %%
import pickle

rf_model = pickle.load(open("random_forest_churn_model.pkl", "rb"))
sc = pickle.load(open("scaler.pkl", "rb"))

# Predict for new data
prediction = rf_model.predict(X_test)
